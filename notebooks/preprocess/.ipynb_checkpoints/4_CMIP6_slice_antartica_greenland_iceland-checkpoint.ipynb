# %% [markdown]
# # CMIP6 Slice Antartica and Greenland/Iceland
#
# **Following steps are included in this script:**
#
# 1. Load netCDF files
# 2. Remove Antartica by removing data south of 60° and Greenland/Iceland using regionmask
#
# 4. Save and replace netcdf files

# %%
# ========== Packages ==========
import sys
import os
import xarray as xr
import pandas as pd
import numpy as np
import dask
from dask.diagnostics import ProgressBar
import importlib
import regionmask

# Define the full path to the data_handling directory and the config file
data_handling_dir = '/work/ch0636/g300115/phd_project/common/src/data_handling'
config_dir = '/work/ch0636/g300115/phd_project/common/src'

# Add the directories to sys.path
sys.path.append(data_handling_dir)
sys.path.append(config_dir)

# Now import the functions from load_preprocessed_data.py and config
import load_data as ld
import save_data_as_nc as sd
from config import BASE_DIR, DEFAULT_MODEL, DEFAULT_VARIABLE, DEFAULT_TEMPORAL_RES, DEFAULT_EXPERIMENT

# %% [markdown]
# ### Functions

# %%
def remove_antarctica_greenland_iceland(ds_dict):
    # Define the regions using regionmask
    land_regions = regionmask.defined_regions.ar6.land
    
    # Identify the index for the GIC Greenland/Iceland region
    gic_region_idx = land_regions.map_keys('Greenland/Iceland')
    
    for name, ds in ds_dict.items():
        # Get the mask for the GIC Greenland/Iceland region
        gic_region_mask = land_regions.mask(ds)
        
        # Slice the dataset to exclude Antarctica latitudes
        ds_no_antarctica = ds.sel(lat=(ds.lat > -60))
        
        # Apply the mask to exclude the GIC Greenland/Iceland region
        mask = gic_region_mask == gic_region_idx
        ds_no_gic = ds_no_antarctica.where(~mask, drop=True)

        print(f'Regions removed from {name}.')
        
        # Add comment about changes to data
        if 'log' in ds_no_gic.attrs:
            log_old = ds_no_gic.attrs['log']
            ds_no_gic.attrs['log'] = f'Dataset sliced along lat 60 to remove Antarctica and excluded Greenland and Iceland using regionmask. // {log_old}'
        else:
            ds_no_gic.attrs['log'] = 'Dataset sliced along lat 60 to remove Antarctica and excluded Greenland and Iceland using regionmask.'
        
        ds_dict[name] = ds_no_gic
    
    return ds_dict

# %% [markdown]
# ### 1. Load netCDF files

# %%
# ========= Define period, models and path ==============
data_state = 'processed'
data_product = 'CMIP6'
experiments = ['ssp370']
temp_res = 'month'
models = ['BCC-CSM2-MR', 'CAMS-CSM1-0', 'CESM2-WACCM', 'CNRM-ESM2-1', 'GISS-E2-1-G', 'MIROC-ES2L', 'NorESM2-MM', 'UKESM1-0-LL', 'CanESM5', 'CNRM-CM6-1', 'GFDL-ESM4', 'MPI-ESM1-2-LR', 'TaiESM1']
variables=['ps', 'huss', 'evspsbl', 'tran', 'gpp', 'tas', 'pr', 'lai', 'mrso', 'mrro'] 
           
# Execute load function with Dask
with ProgressBar():
    ds_dict = dask.compute(ld.load_multiple_models_and_experiments(BASE_DIR, data_state, data_product, experiments, temp_res, models, variables))[0]
# Out:
# No file found for variable 'huss' in model 'CAMS-CSM1-0'.
# No file found for variable 'gpp' in model 'CAMS-CSM1-0'.
# Model 'CAMS-CSM1-0' is missing variables: huss, gpp
# No file found for variable 'gpp' in model 'GFDL-ESM4'.
# Model 'GFDL-ESM4' is missing variables: gpp
# [########################################] | 100% Completed | 57.08 s

# %%
# ========= Have a look into the dictionary =======
print(list(ds_dict.keys()))
ds_dict[list(ds_dict.keys())[0]][models[0]][variables[0]].isel(time=0).plot()
# Out:
# ['ssp370']

# %% [markdown]
# ### 2. Remove Antartica and Greenland/Iceland

# %%
ds_dict = remove_antarctica_greenland_iceland(ds_dict[experiments[0]])
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /work/ch0636/g300115/.conda/envs/mypy3/share/proj failed

# %%
# Slice the dataset to exclude Antarctica latitudes
for i, (name, ds) in enumerate(ds_dict.items()):
    ds_no_antarctica = ds.sel(lat=(ds.lat > -60))
    # Add comment about changes to data
    if 'log' in ds_no_antarctica.attrs:
        log_old = ds_no_antarctica.attrs['log']
        ds_no_antarctica.attrs['log'] = f'Dataset sliced along lat 60 to remove Antartica. // {log_old}'
    else:
        ds_no_antarctica.attrs['log'] = 'Dataset sliced along lat 60 to remove Antartica.'
    ds_dict[name] = ds_no_antarctica

# %%
ds_dict[list(ds_dict.keys())[12]][variables[7]].isel(time=0).plot()

# %% [markdown]
# ### 4. Save and replace netcdf files

# %%
# =========== Store file and remove any former one ==========
# Base directory
data_path = f'{data_state}/{data_product}/{experiments[0]}/{temp_res}/'
file_path = os.path.join(BASE_DIR, data_path)
print(file_path)
# Out:
# /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/

# %%
sd.save_files(ds_dict, file_path)
# Out:
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/BCC-CSM2-MR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/BCC-CSM2-MR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CAMS-CSM1-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CAMS-CSM1-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CESM2-WACCM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CESM2-WACCM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CNRM-ESM2-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CNRM-ESM2-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GISS-E2-1-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GISS-E2-1-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MIROC-ES2L.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MIROC-ES2L.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/NorESM2-MM.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/NorESM2-MM.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/UKESM1-0-LL.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/UKESM1-0-LL.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CanESM5.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CanESM5.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CNRM-CM6-1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CNRM-CM6-1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GFDL-ESM4.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GFDL-ESM4.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MPI-ESM1-2-LR.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MPI-ESM1-2-LR.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/ps/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/huss/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/evspsbl/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/gpp/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tas/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/lai/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrso/TaiESM1.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/TaiESM1.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/TaiESM1.nc
