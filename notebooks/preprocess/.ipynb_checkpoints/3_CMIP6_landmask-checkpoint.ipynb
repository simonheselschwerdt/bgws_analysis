# %% [markdown]
# # CMIP6 Landmask
#
# **Following steps are included in this script:**
#
# 1. Load netCDF files
# 2. Create Landmask (use preprocessed data set)
# 3. Apply Landmask
# 4. Save and replace netcdf files

# %%
# ========== Packages ==========
import sys
import os
import xarray as xr
import pandas as pd
import numpy as np
import dask
import math
from dask.diagnostics import ProgressBar
import importlib

# Define the full path to the data_handling directory and the config file
data_handling_dir = '/work/ch0636/g300115/phd_project/common/src/data_handling'
config_dir = '/work/ch0636/g300115/phd_project/common/src'

# Add the directories to sys.path
sys.path.append(data_handling_dir)
sys.path.append(config_dir)

# Now import the functions from load_preprocessed_data.py and config
import load_data as ld
import save_data_as_nc as sd
from config import BASE_DIR, DEFAULT_MODEL, DEFAULT_VARIABLE, DEFAULT_TEMPORAL_RES, DEFAULT_EXPERIMENT

# %% [markdown]
# ### Functions

# %%
def find_first_datapoint(ds_dict, variable):
    
    data = ds_dict[list(ds_dict.keys())[0]][variable]

    # Find the first time index with non-NaN values
    non_nan_time_index = data.notnull().any(dim=["lat", "lon"]).argmax().values

    # Find the first time index with non-zero values
    non_zero_time_index = (data != 0).any(dim=["lat", "lon"]).argmax().values

    # Find the maximum of both time indices to get the first time index with actual values
    first_actual_values_time_index = max(non_nan_time_index, non_zero_time_index)

    first_actual_values_time = data.time.isel(time=first_actual_values_time_index).values

    print("First time index with actual values:", first_actual_values_time_index)
    print("First time with actual values:", first_actual_values_time)

# %%
def apply_landmask(ds_dict):
    
    # Load landmask
    filename = 'land_sea_mask_1x1_grid.nc'
    savepath = '/work/ch0636/g300115/phd_project/common/data/external/landmask/'
    print(os.path.join(savepath, filename))
    landmask = ld.open_dataset(os.path.join(savepath, filename))
    landmask.landseamask.plot()

    # Apply landmask on data
    for i, (name, ds) in enumerate(ds_dict.items()):
        masked_ds = ds * landmask.landseamask
        print(f'Landmask applied on {name}.')
        
        masked_ds.attrs = ds.attrs
        # Add comment about changes to data 
        if 'log' in masked_ds.attrs:
            log_old = masked_ds.attrs['log']
            masked_ds.attrs['log'] = f'IMERG Land-Sea Mask NetCDF 25%-landmask applied. // {log_old}'
        else:
            masked_ds.attrs['log'] = 'IMERG Land-Sea Mask NetCDF 25%-landmask applied.'   
            
        for var in ds.variables:
            masked_ds[var].attrs = ds[var].attrs
        
        ds_dict[name] = masked_ds
    
    return ds_dict

# %%
def def_landmask(ds_dict):
    
    ### Time coordinates and grid must be equal###
    
    # use lai as land variable to create landmask (check before if reference dataset has values at all land points)
    landmask = (ds_dict[list(ds_dict.keys())[0]]['lai']).astype(int)
    
    # print unique values
    print(f"Unique values:", np.unique(landmask.isel(time=0).values))
    
    # set all numbers below or equal to zero to nan
    landmask = landmask.where(landmask >= 0)
    
    # set all numbers above zero to 1
    landmask = landmask.where(landmask.isnull(), 1)
    
    # save landmask
    filename = f'CMIP.{ds_dict[list(ds_dict.keys())[0]].experiment_id}.landmask_{ds_dict[list(ds_dict.keys())[0]].source_id}.nc'
    savepath = f'../../data/CMIP6/{ds_dict[list(ds_dict.keys())[0]].experiment_id}/landmask/'
    nc_out = os.path.join(savepath, filename)
    os.makedirs(savepath, exist_ok=True) 
    if os.path.exists(nc_out):
        inp = input(f"Delete old file {filename} (y/n):")
        if inp.lower() in ["y"]:
            os.remove(nc_out)
            print(f"File  with path: {nc_out} removed")
        else:
            filename = "temp_file.nc"
            nc_out = os.path.join(savepath, filename)
            print(f"Filename change to {filename}")
    # Save to netcdf file
    landmask.to_netcdf(nc_out)
    print(f"File with path: {nc_out} saved")
    
    return nc_out

# %% [markdown]
# ### 1. Load netCDF files

# %%
# ========= Define period, models and path ==============
data_state = 'processed'
data_product = 'CMIP6'
experiments = ['ssp370']
temp_res = 'month'
models = ['CAS-ESM2-0', 'CMCC-ESM2',  'FGOALS-g3', 'GISS-E2-1-H', 'CanESM5-CanOE', 
          'IPSL-CM5A2-INCA', 'KACE-1-0-G','MIROC6', 'MRI-ESM2-0','EC-Earth3-Veg']#,
          #, 'CMCC-CM2-SR5', 'IPSL-CM6A-LR']#['BCC-CSM2-MR', 'CAMS-CSM1-0', 'CESM2-WACCM', 'CNRM-ESM2-1', 'GISS-E2-1-G', 'MIROC-ES2L', 'UKESM1-0-LL', 'CanESM5', 'CNRM-CM6-1',  'MPI-ESM1-2-LR', 'NorESM2-MM', 'TaiESM1'] #'GFDL-ESM4',
variables=[
               # 'tas',
               #  'ps', 
                 'pr',
               #  'huss', 
               #  'evspsbl', 
        
                'tran', 
               # 'mrso', 
               # 'lai', 
               # 'gpp', 
                'mrro', 
]

# Execute load function with Dask
with ProgressBar():
    ds_dict = dask.compute(ld.load_multiple_models_and_experiments(BASE_DIR, data_state, data_product, experiments, temp_res, models, variables))[0]
# Out:
# [########################################] | 100% Completed | 8.65 ss

# %%
# ========= Have a look into the dictionary =======
print(list(ds_dict.keys()))
ds_dict[list(ds_dict.keys())[0]][models[9]][variables[2]].isel(time=0).plot()
# Out:
# ['ssp370']

# %% [markdown]
# ### 2. Apply Landmask

# %%
ds_dict = apply_landmask(ds_dict[experiments[0]])
# Out:
# /work/ch0636/g300115/phd_project/common/data/external/landmask/land_sea_mask_1x1_grid.nc
# Landmask applied on CAS-ESM2-0.
# Landmask applied on CMCC-ESM2.
# Landmask applied on FGOALS-g3.
# Landmask applied on GISS-E2-1-H.
# Landmask applied on CanESM5-CanOE.
# Landmask applied on IPSL-CM5A2-INCA.
# Landmask applied on KACE-1-0-G.
# Landmask applied on MIROC6.
# Landmask applied on MRI-ESM2-0.
# Landmask applied on EC-Earth3-Veg.

# %%
ds_dict[list(ds_dict.keys())[6]][variables[2]].isel(time=0).plot()

# %% [markdown]
# ### 3. Save and replace netcdf files

# %%
# =========== Store file and remove any former one ==========
# Base directory
data_path = f'{data_state}/{data_product}/{experiments[0]}/{temp_res}/'
file_path = os.path.join(BASE_DIR, data_path)
print(file_path)
# Out:
# /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/

# %%
sd.save_files(ds_dict, file_path)
# Out:
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CAS-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CAS-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CAS-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CAS-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CAS-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CAS-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CMCC-ESM2.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CMCC-ESM2.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CMCC-ESM2.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CMCC-ESM2.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CMCC-ESM2.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CMCC-ESM2.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/FGOALS-g3.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/FGOALS-g3.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/FGOALS-g3.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/FGOALS-g3.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/FGOALS-g3.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/FGOALS-g3.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GISS-E2-1-H.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/GISS-E2-1-H.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GISS-E2-1-H.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/GISS-E2-1-H.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GISS-E2-1-H.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/GISS-E2-1-H.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CanESM5-CanOE.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/CanESM5-CanOE.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CanESM5-CanOE.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/CanESM5-CanOE.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CanESM5-CanOE.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/CanESM5-CanOE.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/IPSL-CM5A2-INCA.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/IPSL-CM5A2-INCA.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/IPSL-CM5A2-INCA.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/IPSL-CM5A2-INCA.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/IPSL-CM5A2-INCA.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/IPSL-CM5A2-INCA.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/KACE-1-0-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/KACE-1-0-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/KACE-1-0-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/KACE-1-0-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/KACE-1-0-G.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/KACE-1-0-G.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MIROC6.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MIROC6.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MIROC6.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MIROC6.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MIROC6.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MIROC6.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MRI-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/MRI-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MRI-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/MRI-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MRI-ESM2-0.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/MRI-ESM2-0.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/EC-Earth3-Veg.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/pr/EC-Earth3-Veg.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/EC-Earth3-Veg.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/tran/EC-Earth3-Veg.nc
# File /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/EC-Earth3-Veg.nc removed
# File saved at: /work/ch0636/g300115/phd_project/common/data/processed/CMIP6/ssp370/month/mrro/EC-Earth3-Veg.nc
